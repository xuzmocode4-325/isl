# %% [markdown]
# # Classification Exercises

# %% [markdown]
# ## Conceptual Challenges

# %% [markdown]
# Using a little bit of algebra, prove that $p(X) = \frac{e^\beta}{1+e^\beta}$  is equivalent to  (4.3). In other words, the logistic function representation and logit representation for the logistic regression model are equivalent.
