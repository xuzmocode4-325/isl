# %% [markdown]
# # Applied Statisical Learning

# %%
import numpy as np 
import pandas as pd
from pathlib import Path

# %%
# define path to datasets
data = Path().cwd().parent / 'data'

# %% [markdown]
# ## College Dataset Section

# %%
# Use the pd.read_csv() function to read the data into Python
college = pd.read_csv(data / "College.csv", )

# %%
college.shape
# Out:
# (777, 19)

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# Assigning college name as index value.

# %%
college2 = pd.read_csv(data / 'College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
axis=1)
college3 = college3.set_index('College')

# %%
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college = college3

# %% [markdown]
# Use the `describe()` method of to produce a numerical summary of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# Use the `pd.plotting.scatter_matrix()` function to produce a scatterplot matrix of the frst columns `[Top10perc, Apps, Enroll]`.

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# Use the `boxplot()` method of college to produce side-by-side boxplots of Outstate versus Private

# %%
college.boxplot("Outstate", "Private")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# Create a new qualitative variable, called `Elite`by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%

# %%
# 
college['Elite'] = pd.cut(
    college['Top10perc'], 
    [0,50,100],
    labels=['No', 'Yes']
)

# %% [markdown]
# Use the `value_counts()` method of `college['Elite']` to see how
# many elite universities there are.

# %%
#Use the value_counts() method of college['Elite'] to see how many elite universities there are.
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %% [markdown]
# Use the `plot.hist()` method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables.

# %%
#Use the plot.hist() method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables
from matplotlib import pyplot as plt
number_cols = college.select_dtypes(include=['int64', 'float64']).columns
fig, axs = plt.subplots(6, 3, figsize=(18, 15))
for ax, col in zip(axs.flat, number_cols): 
    ax.set_title(f"{col} histogram")
    ax.hist(college[col])
fig.tight_layout()

# %% [markdown]
# Explore the data, and provide a brief summary of
# what you discover.

# %%
college['Private'].value_counts()[0]
# Out:
# C:\Users\katle\AppData\Local\Temp\ipykernel_15964\1347535992.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   college['Private'].value_counts()[0]
# 565

# %%
perc_private = college['Private'].value_counts() / 777 * 100
perc_private
# Out:
# Private
# Yes    72.715573
# No     27.284427
# Name: count, dtype: float64

# %%
college[college['Apps'] == college['Apps'].max()]
# Out:
#                          Private   Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Rutgers at New Brunswick      No  48094   26330    4520         36         79
#
#                           F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# College
# Rutgers at New Brunswick        21401         3712      7410        4748
#
#                           Books  Personal  PhD  Terminal  S.F.Ratio  \
# College
# Rutgers at New Brunswick    690      2009   90        95       19.5
#
#                           perc.alumni  Expend  Grad.Rate Elite
# College
# Rutgers at New Brunswick           19   10474         77    No

# %%
# Highest Enrollment
college[college['Enroll'] == college['Enroll'].max()]
# Out:
#                                    Private   Apps  Accept  Enroll  Top10perc  \
# College
# Texas A&M Univ. at College Station      No  14474   10519    6392         49
#
#                                     Top25perc  F.Undergrad  P.Undergrad  \
# College
# Texas A&M Univ. at College Station         85        31643         2798
#
#                                     Outstate  Room.Board  Books  Personal  \
# College
# Texas A&M Univ. at College Station      5130        3412    600      2144
#
#                                     PhD  Terminal  S.F.Ratio  perc.alumni  \
# College
# Texas A&M Univ. at College Station   89        91       23.1           29
#
#                                     Expend  Grad.Rate Elite
# College
# Texas A&M Univ. at College Station    8471         69    No

# %%
# Highest Top10 percent
college[college['Top10perc'] == college['Top10perc'].max()]
# Out:
#                                       Private  Apps  Accept  Enroll  \
# College
# Massachusetts Institute of Technology     Yes  6411    2140    1078
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# College
# Massachusetts Institute of Technology         96         99         4481
#
#                                        P.Undergrad  Outstate  Room.Board  \
# College
# Massachusetts Institute of Technology           28     20100        5975
#
#                                        Books  Personal  PhD  Terminal  \
# College
# Massachusetts Institute of Technology    725      1600   99        99
#
#                                        S.F.Ratio  perc.alumni  Expend  \
# College
# Massachusetts Institute of Technology       10.1           35   33541
#
#                                        Grad.Rate Elite
# College
# Massachusetts Institute of Technology         94   Yes

# %%
# Highest Outstate Tuition
college[college['Outstate'] == college['Outstate'].max()]
# Out:
#                    Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Bennington College     Yes   519     327     114         25         53
#
#                     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Bennington College          457            2     21700        4100    600
#
#                     Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Bennington College       500   35        59       10.1           33   16364
#
#                     Grad.Rate Elite
# College
# Bennington College         55    No

# %%
# Highest Books Cost
college[college['Books'] == college['Books'].max()]
# Out:
#                             Private  Apps  Accept  Enroll  Top10perc  \
# College
# Center for Creative Studies     Yes   601     396     203          1
#
#                              Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Center for Creative Studies         20          525          323     11230
#
#                              Room.Board  Books  Personal  PhD  Terminal  \
# College
# Center for Creative Studies        6643   2340       620    8        58
#
#                              S.F.Ratio  perc.alumni  Expend  Grad.Rate Elite
# College
# Center for Creative Studies        6.8            4   13025         47    No

# %%
# Highest Room & Bording Cost
college[college['Room.Board'] == college['Room.Board'].max()]
# Out:
#                 Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Barnard College     Yes  2496    1402     531         53         95
#
#                  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Barnard College         2121           69     17926        8124    600
#
#                  Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Barnard College       850   83        93       10.3           33   12580
#
#                  Grad.Rate Elite
# College
# Barnard College         91   Yes

# %%
# Highest Graduation Rate
college[college['Grad.Rate'] == college['Grad.Rate'].max()]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate Elite
# College
# Cazenovia College        118    No

# %%
# Highest Percentage faculty wit PhD 
college[college['PhD'] == college['PhD'].max()]
# Out:
#                                   Private  Apps  Accept  Enroll  Top10perc  \
# College
# Texas A&M University at Galveston      No   529     481     243         22
#
#                                    Top25perc  F.Undergrad  P.Undergrad  \
# College
# Texas A&M University at Galveston         47         1206          134
#
#                                    Outstate  Room.Board  Books  Personal  PhD  \
# College
# Texas A&M University at Galveston      4860        3122    600       650  103
#
#                                    Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Texas A&M University at Galveston        88       17.4           16    6415
#
#                                    Grad.Rate Elite
# College
# Texas A&M University at Galveston         43    No

# %%
college['perc.enroll'] = np.round(college['Enroll'] / college['Apps'] * 100)

# %%
top10_enroll = college.sort_values('perc.enroll', ascending=False).head(10)
top10_enroll
# Out:
#                                         Private  Apps  Accept  Enroll  \
# College
# Brewton-Parker College                      Yes  1436    1228    1202
# Mississippi University for Women             No   480     405     380
# Hardin-Simmons University                   Yes   467     424     350
# Dickinson State University                   No   434     412     319
# University of Sci. and Arts of Oklahoma      No   285     280     208
# East Texas Baptist University               Yes   379     341     265
# Emporia State University                     No  1256    1256     853
# MidAmerica Nazarene College                 Yes   331     331     225
# Mayville State University                    No   233     233     153
# University of Arkansas at Fayetteville       No  3235    3108    2133
#
#                                          Top10perc  Top25perc  F.Undergrad  \
# College
# Brewton-Parker College                          10         26         1320
# ...

# %%
top10_elite = college[college['Elite'] == 'Yes'].sort_values('Top10perc', ascending=False).head(10)
top10_elite
# Out:
#                                       Private   Apps  Accept  Enroll  \
# College
# Massachusetts Institute of Technology     Yes   6411    2140    1078
# University of California at Berkeley       No  19873    8252    3215
# Harvey Mudd College                       Yes   1377     572     178
# Yale University                           Yes  10705    2453    1317
# Duke University                           Yes  13789    3893    1583
# Harvard University                        Yes  13865    2165    1606
# Princeton University                      Yes  13218    2042    1153
# Georgia Institute of Technology            No   7837    4527    2276
# Dartmouth College                         Yes   8587    2273    1087
# Brown University                          Yes  12586    3239    1462
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# College
# Massachusetts Institute of Technology         96         99         4481
# ...

# %%
top10_grad = college[college['Elite'] == 'Yes'].sort_values('Grad.Rate', ascending=False).head(10)
top10_grad
# Out:
#                      Private   Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Amherst College          Yes   4302     992     418         83         96
# Harvey Mudd College      Yes   1377     572     178         95        100
# Harvard University       Yes  13865    2165    1606         90        100
# Grove City College       Yes   2491    1110     573         57         88
# Yale University          Yes  10705    2453    1317         95         99
# Columbia University      Yes   6756    1930     871         78         96
# Princeton University     Yes  13218    2042    1153         90         98
# Williams College         Yes   4186    1245     526         81         96
# Dartmouth College        Yes   8587    2273    1087         87         99
# Brown University         Yes  12586    3239    1462         87         95
#
#                       F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# ...

# %%
top10_PhD = college[college['Elite'] == 'Yes'].sort_values('PhD', ascending=False).head(10)
top10_PhD
# Out:
#                                       Private   Apps  Accept  Enroll  \
# College
# Harvey Mudd College                       Yes   1377     572     178
# Bryn Mawr College                         Yes   1465     810     313
# Brown University                          Yes  12586    3239    1462
# Massachusetts Institute of Technology     Yes   6411    2140    1078
# University of Chicago                     Yes   6348    2999     922
# Claremont McKenna College                 Yes   1860     767     227
# Columbia University                       Yes   6756    1930     871
# Harvard University                        Yes  13865    2165    1606
# Emory University                          Yes   8506    4168    1236
# University of Notre Dame                  Yes   7700    3700    1906
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# College
# Harvey Mudd College                           95        100          654
# ...

# %%
names = top10_elite.index
apps = top10_elite['Apps']
accept = top10_elite['Accept']
enroll = top10_elite['Enroll']
width = 0.8

fig, ax = plt.subplots(figsize=(16, 9)) 
ax.barh(names, apps, width)
ax.barh(names, accept, width)
ax.barh(names, enroll, width)
# Out:
# <BarContainer object of 10 artists>

# %%
college['Grad.Rate'].mean()
# Out:
# 65.46332046332046

# %%
top10_elite['Grad.Rate'].mean()
# Out:
# 93.2

# %%
college[college['Elite'] == 'No'].sort_values('Grad.Rate', ascending=False).head(10)
# Out:
#                                 Private  Apps  Accept  Enroll  Top10perc  \
# College
# Cazenovia College                   Yes  3847    3433     527          9
# Missouri Southern State College      No  1576    1326     913         13
# University of Richmond              Yes  5892    2718     756         46
# Lindenwood College                  Yes   810     484     356          6
# Siena College                       Yes  2961    1932     628         24
# College of Mount St. Joseph         Yes   798     620     238         14
# Santa Clara University              Yes  4019    2779     888         40
# York College of Pennsylvania        Yes  2989    1855     691         28
# Saint Mary's College                Yes   888     734     393         26
# Taylor University                   Yes  1769    1092     437         41
#
#                                  Top25perc  F.Undergrad  P.Undergrad  \
# College
# Cazenovia College                       35         1010           12
# ...

# %% [markdown]
# > UC Berkly has the highest application number of all the elite universities. Elite Univerities have an average graduation rate of 93.2%. Overall, the colleges have a mean graduation rate of 65.4%. Of the 777 colleges, 72,72% are private.

# %% [markdown]
# ## Auto Dataset Section

# %%
auto = pd.read_csv(data / 'Auto.csv')

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Which of the predictors are quantitative, and which are qualitative?

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# Quantitative predictores int the `Auto` dataset include:
# - mpg (Miles Per Gallon)
# - displacement
# - horsepower
# - weight
# - acceleration
# - year
# - origin
#
# Qualitative predictors in the  `Auto` dataset include:
# - Cylinders
# - Origin

# %% [markdown]
# Correcting `horspower` datatype in the dataset.

# %%
auto1 = auto.copy()

# %%
auto1['horsepower'].unique() #= pd.to_numeric(auto1['horsepower'])
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
auto1.replace('?', np.nan, inplace=True)

# %%
auto1['horsepower'] = pd.to_numeric(auto1['horsepower'])

# %%
auto_numeric = [col for col in auto1.columns if col not in ['cylinders', 'origin', 'name']]

# %%
auto1.shape
# Out:
# (397, 9)

# %% [markdown]
#  What is the range of each quantitative predictor? You can answer this using the `min()` and `max()` methods in numpy.

# %%
auto1[auto_numeric].max() - auto1[auto_numeric].min()
# Out:
# mpg               37.6
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# dtype: float64

# %% [markdown]
# What is the `mean` and `standard deviation` of each quantitative
# predictor?

# %%
auto1[auto_numeric].mean()
# Out:
# mpg               23.515869
# displacement     193.532746
# horsepower       104.469388
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# dtype: float64

# %%
auto1[auto_numeric].std()
# Out:
# mpg               7.825804
# displacement    104.379583
# horsepower       38.491160
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# dtype: float64

# %% [markdown]
# Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
auto_trim = pd.concat([auto1.iloc[0:9], auto1.iloc[85:]])

# %%
auto_trim.shape
# Out:
# (321, 9)

# %%
auto_trim[auto_numeric].max() - auto_trim[auto_numeric].min()
# Out:
# mpg               35.6
# displacement     387.0
# horsepower       184.0
# weight          3348.0
# acceleration      16.3
# year              12.0
# dtype: float64

# %%
auto_trim[auto_numeric].mean()
# Out:
# mpg               24.438629
# displacement     187.049844
# horsepower       100.955836
# weight          2933.962617
# acceleration      15.723053
# year              77.152648
# dtype: float64

# %%
auto_trim[auto_numeric].std()
# Out:
# mpg               7.908184
# displacement     99.635385
# horsepower       35.895567
# weight          810.642938
# acceleration      2.680514
# year              3.111230
# dtype: float64

# %% [markdown]
# Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your fndings

# %%
auto_corr = auto1[auto_numeric].corr()
mask = np.zeros_like(auto_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

auto_corr[mask] = np.nan
(auto_corr
    .style
    .background_gradient(
        cmap='coolwarm', vmin=-1, vmax=1
    )
    .highlight_null(color='#f1f1f1')
    .format(precision=2)
)
# Out:
# <style type="text/css">
# #T_d723a_row0_col0, #T_d723a_row0_col1, #T_d723a_row0_col2, #T_d723a_row0_col3, #T_d723a_row0_col4, #T_d723a_row0_col5, #T_d723a_row1_col1, #T_d723a_row1_col2, #T_d723a_row1_col3, #T_d723a_row1_col4, #T_d723a_row1_col5, #T_d723a_row2_col2, #T_d723a_row2_col3, #T_d723a_row2_col4, #T_d723a_row2_col5, #T_d723a_row3_col3, #T_d723a_row3_col4, #T_d723a_row3_col5, #T_d723a_row4_col4, #T_d723a_row4_col5, #T_d723a_row5_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_d723a_row1_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d723a_row2_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d723a_row2_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_d723a_row3_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d723a_row3_col1 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_d723a_row3_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# ...

# %% [markdown]
# > **Auto dataset observations.**
# >
# >1. Feul efficency and acceleration of cars tends to improve over the years.
# >2. Lighter cars have faster acceleration and higher feul economy.
# >3. Vehicle mass, horsepower and displacement have strong positive corellations.

# %% [markdown]
# Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.

# %% [markdown]
# > According to the correlation heatmap visual, displacement, horsepower, vehicle weight and acceleration as well as year of manufacture could all be useful in predicting gas mileage. The mass of a vehicle could very likely have an impact on the amount of feul it consumes, the year in which it has been manufactured could make a difference in the mileage due to progress made in engineering and the improvements on performance of on vehicles through incorporation of new technologies that improve feul efficiency.

# %% [markdown]
# ### Housing Dataset Section

# %%
housing = pd.read_csv(data / 'Boston.csv')

# %% [markdown]
# How many rows are in this data set?
# > 506
#
# How many columns?
# > 14
#
# What do the rows and columns represent?
# > Each row represents a suburb and each column represents a metric. The metrics are as follows:
#
# > `crim`: per capita crime rate by town.
# `zn`: proportion of residential land zoned for lots over 25,000 sq.ft.
# `indus`: proportion of non-retail business acres per town.
# `chas`: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# `nox`: nitrogen oxides concentration (parts per 10 million).
# `rm`: average number of rooms per dwelling.
# `age`: proportion of owner-occupied units built prior to 1940.
# `dis`: weighted mean of distances to five Boston employment centres.
# `rad`: index of accessibility to radial highways.
# `tax`: full-value property-tax rate per $10,000.
# `ptratio`: pupil-teacher ratio by town.
# `lstat`: lower status of the population (percent).
# `medv`: median value of owner-occupied homes in $1000s.

# %%
housing.shape
# Out:
# (506, 14)

# %%
house_catagorical = ['zn', 'indus', 'chas', 'rad', 'ptratio', 'tax']
house_numerical = [
    col for col in housing.columns if col not in house_catagorical
]

# %%
housing.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# lstat      float64
# medv       float64
# dtype: object

# %%
housing = housing.rename(
    {'Unnamed: 0': 'suburb'},
    axis=1
)

housing = housing.set_index('suburb')

# %%
housing.head()
# Out:
#            crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# suburb
# 1       0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2       0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3       0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4       0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5       0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
#
#         ptratio  lstat  medv
# suburb
# 1          15.3   4.98  24.0
# 2          17.8   9.14  21.6
# 3          17.8   4.03  34.7
# 4          18.7   2.94  33.4
# 5          18.7   5.33  36.2

# %% [markdown]
# Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your fndings.

# %%
pd.plotting.scatter_matrix(housing[house_numerical], figsize=(16, 16))
print()

# %% [markdown]
# Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %% [markdown]
# > Yes. Per capita crime rate:
# > 1. has a positive correlations with nitrous oxide concentration.
# > 2. has a negative correlation with room number.
# > 3. has a positive correlation with age.
# > 4. has a negative correlation with distance from employment centers.
# > 5. has a positive correlation with lower status of the population percentages.
# > 6. has a negative correlation with the value of owner-occupied homes.

# %% [markdown]
# Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.

# %%
housing.sort_values(by='crim', ascending=False).head()
# Out:
#            crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# suburb
# 381     88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 419     73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 406     67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 411     51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 415     45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
#
#         ptratio  lstat  medv
# suburb
# 381        20.2  17.21  10.4
# 419        20.2  20.62   8.8
# 406        20.2  22.98   5.0
# 411        20.2  10.11  15.0
# 415        20.2  36.98   7.0

# %%
housing.sort_values(by='ptratio', ascending=True).head()
# Out:
#            crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# suburb
# 198     0.04666  80.0   1.52     0  0.404  7.107  36.6  7.3090    2  329
# 199     0.03768  80.0   1.52     0  0.404  7.274  38.3  7.3090    2  329
# 197     0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 263     0.52014  20.0   3.97     0  0.647  8.398  91.5  2.2885    5  264
# 262     0.53412  20.0   3.97     0  0.647  7.520  89.4  2.1398    5  264
#
#         ptratio  lstat  medv
# suburb
# 198        12.6   8.61  30.3
# 199        12.6   6.62  34.6
# 197        12.6   4.08  33.3
# 263        13.0   5.91  48.8
# 262        13.0   7.26  43.1

# %%
housing['crim'].max() - housing['crim'].min()
# Out:
# 88.96988

# %%
housing['ptratio'].max() - housing['ptratio'].min()
# Out:
# 9.4

# %% [markdown]
# > 1. Suburbs 381, 419 and 406 show particularly high crime rates (over 65%)
# > 2. Suburbs 355 and 356 have the highest pupil to teacher ratio of 22.
# > 3. Theres an almost 90 percent difference in crime rate from the suburb with the lowest crime rate to the suburb with the highest.
# > 4. There's an about 9 pupil difference between the pupil to teacher ratio of the highest suburb and the lowest.

# %% [markdown]
# How many of the suburbs in this data set bound the Charles
# river?

# %%
housing['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# > 35 suburbs in this data set bound the Charles river.

# %% [markdown]
# What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
housing['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# > The median pupil-teacher ratio among the towns in this data set is 19.05

# %% [markdown]
# Which suburb of Boston has lowest median value of owner occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your fndings...

# %%
housing.sort_values(by='medv', ascending=True).head()
# Out:
#             crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# suburb
# 399     38.35180  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 406     67.92080  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 401     25.04610  0.0   18.1     0  0.693  5.987  100.0  1.5888   24  666
# 400      9.91655  0.0   18.1     0  0.693  5.852   77.8  1.5004   24  666
# 415     45.74610  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
#
#         ptratio  lstat  medv
# suburb
# 399        20.2  30.59   5.0
# 406        20.2  22.98   5.0
# 401        20.2  26.77   5.6
# 400        20.2  29.97   6.3
# 415        20.2  36.98   7.0

# %%
housing.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# > Suburb 399 and 406 share a spot for the lowest mediand value of owner occupied homes. The predictor values for each respective column are as follows:
#
# |Suburb |399 |409 |
# |-------|----|----|
# |crim | 38.4 | 67.9 |
# |lsat | 30.6 | 22.98 |
# |dis | 1.5 | 1.4 |
# |rm | 5.5 | 5.6 |

# %% [markdown]
# > Additionally, the two suburbs share the following values:
#
# > zn: 0.0
# > indus: 18.1
# > chas: 0
# > nox: 63.3
# > age: 100
# > rad: 24
# > tax: 666
# > ptratio: 20.2
#
# > The age of the neighbourhood seems to be the defining factor in the low value of the properties in the neighbourhood as most were built prior to 1940.

# %% [markdown]
# In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling

# %%
housing['rm'][housing['rm'] > 7].count()
# Out:
# 64

# %%
housing['rm'][housing['rm'] > 8].count()
# Out:
# 13

# %%
housing[housing['rm'] > 8]
# Out:
#            crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# suburb
# 98      0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 164     1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 205     0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 225     0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 226     0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 227     0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 233     0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 234     0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 254     0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 258     0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 263     0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 268     0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %%
housing[housing['rm'] > 8].mean()
# Out:
# crim         0.718795
# zn          13.615385
# indus        7.078462
# chas         0.153846
# nox          0.539238
# rm           8.348538
# age         71.538462
# dis          3.430192
# rad          7.461538
# tax        325.076923
# ptratio     16.361538
# lstat        4.310000
# medv        44.200000
# dtype: float64

# %% [markdown]
# > There are 64 suburbs with an average of 7 rooms or more per house.
#
# > There are 13 suburbs with an average of 8 rooms or more per house.
#
# > The suburbs with houses averaging 8 rooms have an extremely low crime rates averaging 0.72 percent. They have very low nitroux oxide values averaging 0.54 percent.The average median value of owner occupied homes is high at around 442 000 USD. The suburbs in this bracket that bound the Charles river have significantly higher crime rates than their counterparts which do not.
