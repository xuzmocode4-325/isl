# %% [markdown]
# # Statistical Learning Exercises

# %% [markdown]
# ### Conceptual Challenges

# %% [markdown]
# 1. For each of parts (a) through (d), indicate whether we would generally
# expect the performance of a fexible statistical learning method to be
# better or worse than an infexible method. Justify your answer.

# %% [markdown]
# &emsp;&emsp; (a) The sample size n is extremely large, and the number of predictors `p` is small.

# %% [markdown]
# > Better. If the sample size n is large and the number of predictors p is small then a flexible statistical learning method would perform better because a flexible function requires many observations to estimate the function of a data set and because there are a few predictors p it will be a challenge for a statistical model to estimate coefficients for *f* accurately.

# %% [markdown]
# &emsp;&emsp; (b) The number of predictors p is extremely large, and the number of observations n is small.

# %% [markdown]
# > Worse. If the number of predictors p is vast and the number of observations n is small then it is better to use a non-flexible method because with fewer observations it is hard for a flexible model to estimate f accurately. It is computationally less expensive to assume a functional form in which predictors are used to estimate coefficients rather than dimensions.

# %% [markdown]
# &emsp;&emsp; (c) The relationship between the predictors and response is highly non-linear.

# %% [markdown]
# > Better. When the relationship between the predictors and the response is highly non-linear a flexible model would work better because an inflexible model would introduce a lot of bias in its estimation of `f`.

# %% [markdown]
# &emsp;&emsp; (d) The variance of the error terms, i.e. σ2 = Var("), is extremely high.

# %% [markdown]
# > Worse. When there is a high variance in error an inflexible model may work better to estimate f because it will be less influenced by the noise and reduce the potential overfitting that may occur when using a more flexible model.

# %% [markdown]
# 2. Explain whether each scenario is a classifcation or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide `n` and `p`.

# %% [markdown]
# &emsp;&emsp; (a) We collect a set of data on the top `500 firms in the US`. For each firm we `record proft, number of employees, industry and the CEO salary`. We are interested in understanding which `factors affect CEO salary`.

# %% [markdown]
# >  Regression, Inference, n = 500, p = 4

# %% [markdown]
# &emsp;&emsp; (b) We are considering launching a new product and wish `to know whether it will be a success or a failure`. We `collect data on 20 similar products` that were previously launched. For each product `we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables`.

# %% [markdown]
# > Classification, Prediction, n=20, p=13

# %% [markdown]
# &emsp;&emsp;  (c) We are interested in `predicting the % change in the USD/Euro exchange rate` in relation to the weekly changes in the world
# stock markets. Hence we `collect weekly data for all of 2012`. For each week we `record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market`.

# %% [markdown]
# > Regression, Prediciton, n=52, p=3

# %% [markdown]
# 3. We now revisit the bias-variance decomposition.

# %% [markdown]
# &emsp;&emsp; (a) Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less fexible statistical learning methods
# towards more fexible approaches. The x-axis should represent
# the amount of fexibility in the method, and the y-axis should
# represent the values for each curve. There should be fve curves.
# Make sure to label each one

# %%
from pathlib import Path
from PIL import Image

img = Path.cwd().parent / 'img' /'bias-variance-error.jpg'
Image.open(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=702x515>

# %% [markdown]
# &emsp;&emsp; (b) Explain why each of the fve curves has the shape displayed in
# part (a).

# %% [markdown]
# > `Test error` decreases as flexibility increases approaching irreducible error. With continued increase in flexibility test error increases again as a result of overfitting.
# `Variance increases` as bias decreases because the more flexible a model is more likely it is that it would produce a different function *f* given different inputs.
# `Squared bias` decreases as the model increases in flexibility because the model is able to capture more of the variance and is less rigid to a specific form.
# `Training error` is very large when squard bias is high, it then drastically reduces as the model becomes more flexible, fitting the observations. It approaches zero as a result of overfitting to the training data.

# %% [markdown]
# 4. You will now think of some real-life applications for statistical learning.

# %% [markdown]
# &emsp;&emsp; (a) Describe three real-life applications in which `classifcation` might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer.

# %% [markdown]
# > `Filtering spam`. A model could use NLP to predict whether or not the contents of an e-mail are spam or not.
# `Qualifying Leads`. A model could use client demographic data to estimate whether or not they are likely to purchase a certain product or service.
# `Identifying Fraud`. A model could analyze transaction data to predict whether or not a transaction is fraudulent.

# %% [markdown]
# &emsp;&emsp; (b) Describe three real-life applications in which `regression` might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer.

# %% [markdown]
# > `Predicting Energy Consumption`. A model could take in certain climate data to predict potential energy consumption for a period.
# `Predicting Stock or Currency Prices`. A moddel could use current financial data to predict future stock or currency prices.
# `Predicting Website Hits`. A model could use historical website activity data to predict future hits.

# %% [markdown]
# &emsp;&emsp; (c) Describe three real-life applications in which cluster analysis
# might be useful.

# %% [markdown]
# > `Grouping Similar Clients`. A model could take in customer data and group then according to activity.
# `Grouping Similar Objects`. A moddel could take in unlabelled about objects and group them according to similarity.
# `Reccomending New Media`. A model could recommend new music or movies to platform users based on historing listening or viewing activity.

# %% [markdown]
# 5. What are the advantages and disadvantages of a very fexible (versus
# a less fexible) approach for regression or classifcation? Under what
# circumstances might a more fexible approach be preferred to a less
# fexible approach? When might a less fexible approach be preferred?

# %% [markdown]
# > A very flexible model has less bias and is able to more acturately predict outputs that have a more non-linear relationship to their inputs. The more flexible a model, the more observations it needs to train. Flexible models are more computationally expensive and time consuming to train. Less flexible models, have more bias, and are not able to acurately capure complex relationships between inputs and outputs. They take fewer observations to train and are easier to interprate than more flexible models. A less flexible method might be preffered for inference. A more flexible model is preffered for prediciton when input values have a non-linear relationship with the output and there are many observations to use to train a model.

# %% [markdown]
# 6. Describe the diferences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classifcation (as opposed to a nonparametric approach)? What are its disadvantages?

# %% [markdown]
# > Parametric models compute a function *f* based on an assumed form (e.g linear) to which the predictors are considerd coefficients. Non-parametric models do not assume a form and treat each predictor as a dimension. Parametric approaches are less computationally expensive and work well with datasets that have a small amount of observations and many predictors. Non-parametric approaches work best when there are few predictors, as each predictor adds a new dimension to *f*. Non-parametric models also need many more observations than parametric models to make an accurate estimate of the functional form between input variables and their output.

# %% [markdown]
# 7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.

# %% [markdown]
# &emsp;&emsp; (a) Compute the Euclidean distance between each observation and
# the test point, X1 = X2 = X3 = 0.

# %% [markdown]
# |Obs.  | X1   | X2   | X3   | Y      |
# |------|------|------|------|:------:|
# |1     |  0   | 3    |  0   | Red  |
# |2     |  2   | 0    |  0   | Red  |
# |3     |  0   | 1    |  3   | Red  |
# |4     |  0   | 1    |  2   | Green |
# |5     | −1   | 0    |  1   | Green |
# |6     |  1   | 1    |  1   | Red  |

# %%
# calculating euclidean distance
import numpy as np
import pandas as pd


#creating a dictionary with all observations as values
obs = {
    '1':[0,3,0],
    '2':[2,0,0],
    '3':[0,1,3],
    '4':[0,1,2],
    '5':[-1,0,1],
    '6':[1,1,1],
    '7':[0,0,0],
}

cols = [k for (k,v) in obs.items()]


def dist_matrix(obs, algo, columns): 
    euclid_dict = {}
    for k1, v1 in obs.items():
        dists = []
        val1 = np.array(v1)
        for k2, v2 in obs.items():
            val2 = np.array(v2)
            sum_sq = np.sum(np.square(val1 - val2))
            dists.append(sum_sq)
        euclid_dict[f'{k1} - {str(v1)}'] = dists
    return pd.DataFrame.from_dict(euclid_dict, orient='index', columns=cols)

# %% [markdown]
# &emsp;&emsp; (b) What is our prediction with K = 1? Why?

# %% [markdown]
# > The prediction with K=1 will be `Green` because the closest observation to the test point is `Obs. 5` which also has a value of `Green`.

# %% [markdown]
# &emsp;&emsp; (c) What is our prediction with K = 3? Why?

# %% [markdown]
# > The prediction with K=3 will be `Red` because out of the three closest observations 2 out of the 3 nearest neighbours are classified `Red`.:
# > - `Obs. 5` has a Euclidean distance of 2 and is `Green`.
# > - `Obs. 6` has a Euclidean distance of 3 and is `Red`.
# > - `Obs. 2` has a Euclidean distance of 4 and is `Red`.

# %% [markdown]
# &emsp;&emsp; (d) If the Bayes decision boundary in this problem is highly nonlinear, then would we expect the best value for K to be large or
# small? Why?

# %% [markdown]
# > A smaller value for K is better if the descision boundry is highly non-linear. A larger value would bias the classification along the boundary which could distort predictions, resulting in an increased test error rate.

# %% [markdown]
# Different distance metrics formulas function.

# %%
# calculating euclidean distance
import numpy as np
import pandas as pd


#creating a dictionary with all observations as values
obs = {
    '1':[0,3,0],
    '2':[2,0,0],
    '3':[0,1,3],
    '4':[0,1,2],
    '5':[-1,0,1],
    '6':[1,1,1],
    '7':[0,0,0],
}

cols = [k for (k,v) in obs.items()]

# %%
def dist_matrix(obs, algo, cols): 
    euclid = lambda x,y: np.sqrt(np.sum((x - y) ** 2))
    manhattan = lambda x,y: np.sum(np.abs(x - y))
    chebyshev = lambda x,y: np.max(np.abs(x - y))
    minkowski = lambda x,y,r: np.sum(np.abs(x - y) ** r) ** (1 / r)
    cosine = lambda x,y: np.dot(x,y) / (np.linalg.norm(x) * np.linalg.norm(y)) 
    euclid_dict = {}
    for k1, v1 in obs.items():
        dists = []
        val1 = np.array(v1)
        for k2, v2 in obs.items():
            val2 = np.array(v2)
            dist = algo(v1, v2)
            dists.append(dist)
        euclid_dict[f'{k1} - {str(v1)}'] = dists
    return pd.DataFrame.from_dict(euclid_dict, orient='index', columns=cols)

# %% [markdown]
# ## Application

# %%
import numpy as np
import pandas as pd
from pathlib import Path

data = Path().cwd().parent.parent / '0-data'

# %% [markdown]
# ### College Dataset

# %% [markdown]
# This exercise relates to the College data set, which can be found in
# the file College.csv on the book website. It contains a number of
# variables for 777 different universities and colleges in the US. The
# variables are:
#
# • `Private`: Public/private indicator
# • `Apps`: Number of applications received
# • `Accept`: Number of applicants accepted
# • `Enroll`: Number of new students enrolled
# • `Top10perc`: New students from top 10 % of high school class
# • `Top25perc`: New students from top 25 % of high school class
# • `F.Undergrad`: Number of full-time undergraduates
# • `P.Undergrad`: Number of part-time undergraduates
# • `Outstate`: Out-of-state tuition
# • `Room.Board`: Room and board costs
# • `Books`: Estimated book costs
# • `Personal`: Estimated personal spending
# • `PhD`: Percent of faculty with Ph.D.s
# • `Terminal`: Percent of faculty with terminal degree
# • `S.F.Ratio`: Student/faculty ratio
# • `perc.alumni`: Percent of alumni who donate
# • `Expend`: Instructional expenditure per student
# • `Grad.Rate`: Graduation rate

# %% [markdown]
# (a) Use the pd.read_csv() function to read the data into Python. Call
# the loaded data college.

# %%
college = pd.read_csv(data / "College.csv", )
college.shape
# Out:
# (777, 19)

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# (b)  Look at the data used in the notebook by creating and running
# a new cell with just the code college in it. You should notice
# that the first column is just the name of each university in a
# column named something like Unnamed: 0. We don’t really want
# pandas to treat this as data. However, it may be handy to have
# these names for later. Try the following commands and similarly
# look at the resulting data frames:

# %%
# Assigning college name as index value.
college2 = pd.read_csv(data / 'College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
axis=1)
college3 = college3.set_index('College')

# %%
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# This has used the first column in the file as an index for the
# data frame. This means that pandas has given each row a name
# corresponding to the appropriate university. Now you should see
# that the first data column is Private. Note that the names of
# the colleges appear on the left of the table. We also introduced
# a new python object above: a dictionary, which is specified by dictionary
# (key, value) pairs. Keep your modified version of the data with
# the following:

# %%
college = college3

# %% [markdown]
# (c) Use the describe() method of to produce a numerical summary
# of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# (d)  Use the pd.plotting.scatter_matrix() function to produce a
# scatterplot matrix of the first columns [Top10perc, Apps, Enroll].
# Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# Matplotlib is building the font cache; this may take a moment.
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# (e) Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private.

# %%
college.boxplot("Outstate", "Private")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# (f)  Create a new qualitative variable, called Elite, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.

# %%
college['Elite'] = pd.cut(
    college['Top10perc'], 
    [0,50,100],
    labels=['No', 'Yes']
)

# %% [markdown]
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %% [markdown]
# (h) Use the plot.hist() method of college to produce some his-
# tograms with differing numbers of bins for a few of the quanti-
# tative variables. The command plt.subplots(2, 2) may be use-
# ful: it will divide the plot window into four regions so that four
# plots can be made simultaneously. By changing the arguments
# you can divide the screen up in other combinations.

# %%
from matplotlib import pyplot as plt
number_cols = college.select_dtypes(include=['int64', 'float64']).columns
fig, axs = plt.subplots(6, 3, figsize=(18, 15))
for ax, col in zip(axs.flat, number_cols): 
    ax.set_title(f"{col} histogram")
    ax.hist(college[col])
fig.tight_layout()

# %% [markdown]
# (h) Continue exploring the data, and provide a brief summary of
# what you discover.

# %%
college['Private'].value_counts()[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/islp/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 college['Private'].value_counts()[0]
#
# File /opt/miniconda3/envs/islp/lib/python3.14/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
# ...

# %%
perc_private = college['Private'].value_counts() / 777 * 100
perc_private
# Out:
# Private
# Yes    72.715573
# No     27.284427
# Name: count, dtype: float64

# %%
college[college['Apps'] == college['Apps'].max()]
# Out:
#                          Private   Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Rutgers at New Brunswick      No  48094   26330    4520         36         79
#
#                           F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# College
# Rutgers at New Brunswick        21401         3712      7410        4748
#
#                           Books  Personal  PhD  Terminal  S.F.Ratio  \
# College
# Rutgers at New Brunswick    690      2009   90        95       19.5
#
#                           perc.alumni  Expend  Grad.Rate Elite
# College
# Rutgers at New Brunswick           19   10474         77    No

# %%
college[college['Enroll'] == college['Enroll'].max()]
# Out:
#                                    Private   Apps  Accept  Enroll  Top10perc  \
# College
# Texas A&M Univ. at College Station      No  14474   10519    6392         49
#
#                                     Top25perc  F.Undergrad  P.Undergrad  \
# College
# Texas A&M Univ. at College Station         85        31643         2798
#
#                                     Outstate  Room.Board  Books  Personal  \
# College
# Texas A&M Univ. at College Station      5130        3412    600      2144
#
#                                     PhD  Terminal  S.F.Ratio  perc.alumni  \
# College
# Texas A&M Univ. at College Station   89        91       23.1           29
#
#                                     Expend  Grad.Rate Elite
# College
# Texas A&M Univ. at College Station    8471         69    No

# %%
college[college['Top10perc'] == college['Top10perc'].max()]
# Out:
#                                       Private  Apps  Accept  Enroll  \
# College
# Massachusetts Institute of Technology     Yes  6411    2140    1078
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# College
# Massachusetts Institute of Technology         96         99         4481
#
#                                        P.Undergrad  Outstate  Room.Board  \
# College
# Massachusetts Institute of Technology           28     20100        5975
#
#                                        Books  Personal  PhD  Terminal  \
# College
# Massachusetts Institute of Technology    725      1600   99        99
#
#                                        S.F.Ratio  perc.alumni  Expend  \
# College
# Massachusetts Institute of Technology       10.1           35   33541
#
#                                        Grad.Rate Elite
# College
# Massachusetts Institute of Technology         94   Yes

# %%
college[college['Outstate'] == college['Outstate'].max()]
# Out:
#                    Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Bennington College     Yes   519     327     114         25         53
#
#                     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Bennington College          457            2     21700        4100    600
#
#                     Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Bennington College       500   35        59       10.1           33   16364
#
#                     Grad.Rate Elite
# College
# Bennington College         55    No

# %%
college[college['Books'] == college['Books'].max()]
# Out:
#                             Private  Apps  Accept  Enroll  Top10perc  \
# College
# Center for Creative Studies     Yes   601     396     203          1
#
#                              Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Center for Creative Studies         20          525          323     11230
#
#                              Room.Board  Books  Personal  PhD  Terminal  \
# College
# Center for Creative Studies        6643   2340       620    8        58
#
#                              S.F.Ratio  perc.alumni  Expend  Grad.Rate Elite
# College
# Center for Creative Studies        6.8            4   13025         47    No

# %%
college[college['Room.Board'] == college['Room.Board'].max()]
# Out:
#                 Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Barnard College     Yes  2496    1402     531         53         95
#
#                  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Barnard College         2121           69     17926        8124    600
#
#                  Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Barnard College       850   83        93       10.3           33   12580
#
#                  Grad.Rate Elite
# College
# Barnard College         91   Yes

# %%
college[college['Grad.Rate'] == college['Grad.Rate'].max()]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate Elite
# College
# Cazenovia College        118    No

# %%
college[college['PhD'] == college['PhD'].max()]
# Out:
#                                   Private  Apps  Accept  Enroll  Top10perc  \
# College
# Texas A&M University at Galveston      No   529     481     243         22
#
#                                    Top25perc  F.Undergrad  P.Undergrad  \
# College
# Texas A&M University at Galveston         47         1206          134
#
#                                    Outstate  Room.Board  Books  Personal  PhD  \
# College
# Texas A&M University at Galveston      4860        3122    600       650  103
#
#                                    Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Texas A&M University at Galveston        88       17.4           16    6415
#
#                                    Grad.Rate Elite
# College
# Texas A&M University at Galveston         43    No

# %%
college['perc.enroll'] = np.round(college['Enroll'] / college['Apps'] * 100)

# %%
top10_enroll = college.sort_values(
    'perc.enroll', ascending=False
).head(10)

top10_enroll
# Out:
#                                         Private  Apps  Accept  Enroll  \
# College
# Brewton-Parker College                      Yes  1436    1228    1202
# Mississippi University for Women             No   480     405     380
# Hardin-Simmons University                   Yes   467     424     350
# Dickinson State University                   No   434     412     319
# University of Sci. and Arts of Oklahoma      No   285     280     208
# East Texas Baptist University               Yes   379     341     265
# Emporia State University                     No  1256    1256     853
# MidAmerica Nazarene College                 Yes   331     331     225
# Mayville State University                    No   233     233     153
# University of Arkansas at Fayetteville       No  3235    3108    2133
#
#                                          Top10perc  Top25perc  F.Undergrad  \
# College
# Brewton-Parker College                          10         26         1320
# ...

# %%
top10_elite = college[
    college['Elite'] == 'Yes'
].sort_values(
    'Top10perc', ascending=False
).head(10)

top10_elite
# Out:
#                                       Private   Apps  Accept  Enroll  \
# College
# Massachusetts Institute of Technology     Yes   6411    2140    1078
# University of California at Berkeley       No  19873    8252    3215
# Harvey Mudd College                       Yes   1377     572     178
# Yale University                           Yes  10705    2453    1317
# Duke University                           Yes  13789    3893    1583
# Harvard University                        Yes  13865    2165    1606
# Princeton University                      Yes  13218    2042    1153
# Georgia Institute of Technology            No   7837    4527    2276
# Dartmouth College                         Yes   8587    2273    1087
# Brown University                          Yes  12586    3239    1462
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# College
# Massachusetts Institute of Technology         96         99         4481
# ...

# %%
top10_grad = college[
    college['Elite'] == 'Yes'
].sort_values(
    'Grad.Rate', ascending=False
).head(10)

top10_grad
# Out:
#                      Private   Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Amherst College          Yes   4302     992     418         83         96
# Harvey Mudd College      Yes   1377     572     178         95        100
# Harvard University       Yes  13865    2165    1606         90        100
# Grove City College       Yes   2491    1110     573         57         88
# Yale University          Yes  10705    2453    1317         95         99
# Columbia University      Yes   6756    1930     871         78         96
# Princeton University     Yes  13218    2042    1153         90         98
# Williams College         Yes   4186    1245     526         81         96
# Dartmouth College        Yes   8587    2273    1087         87         99
# Brown University         Yes  12586    3239    1462         87         95
#
#                       F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# ...

# %%
top10_PhD = college[
    college['Elite'] == 'Yes'
].sort_values(
    'PhD', ascending=False
).head(10)

top10_PhD
# Out:
#                                       Private   Apps  Accept  Enroll  \
# College
# Harvey Mudd College                       Yes   1377     572     178
# Bryn Mawr College                         Yes   1465     810     313
# Brown University                          Yes  12586    3239    1462
# Massachusetts Institute of Technology     Yes   6411    2140    1078
# University of Chicago                     Yes   6348    2999     922
# Claremont McKenna College                 Yes   1860     767     227
# Columbia University                       Yes   6756    1930     871
# Harvard University                        Yes  13865    2165    1606
# Emory University                          Yes   8506    4168    1236
# University of Notre Dame                  Yes   7700    3700    1906
#
#                                        Top10perc  Top25perc  F.Undergrad  \
# College
# Harvey Mudd College                           95        100          654
# ...

# %%
names = top10_elite.index
apps = top10_elite['Apps']
accept = top10_elite['Accept']
enroll = top10_elite['Enroll']
width = 0.8

fig, ax = plt.subplots(figsize=(16, 9)) 
ax.barh(names, apps, width)
ax.barh(names, accept, width)
ax.barh(names, enroll, width)
# Out:
# <BarContainer object of 10 artists>

# %%
college['Grad.Rate'].mean()
# Out:
# np.float64(65.46332046332046)

# %%
top10_elite['Grad.Rate'].mean()
# Out:
# np.float64(93.2)

# %%
college[
    college['Elite'] == 'No'
].sort_values(
    'Grad.Rate', ascending=False
).head(10)
# Out:
#                                 Private  Apps  Accept  Enroll  Top10perc  \
# College
# Cazenovia College                   Yes  3847    3433     527          9
# Missouri Southern State College      No  1576    1326     913         13
# University of Richmond              Yes  5892    2718     756         46
# Lindenwood College                  Yes   810     484     356          6
# Siena College                       Yes  2961    1932     628         24
# College of Mount St. Joseph         Yes   798     620     238         14
# Santa Clara University              Yes  4019    2779     888         40
# York College of Pennsylvania        Yes  2989    1855     691         28
# Saint Mary's College                Yes   888     734     393         26
# Taylor University                   Yes  1769    1092     437         41
#
#                                  Top25perc  F.Undergrad  P.Undergrad  \
# College
# Cazenovia College                       35         1010           12
# ...

# %% [markdown]
# ### Auto Dataset

# %% [markdown]
# 9. This exercise involves the Auto data set studied in the lab. Make sure
# that the missing values have been removed from the data.

# %%
auto_df = pd.read_csv(data / 'Auto.csv')

# %%
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto_df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative?

# %% [markdown]
# Quantitative predictores int the `Auto` dataset include:
# - mpg (Miles Per Gallon)
# - displacement
# - horsepower
# - weight
# - acceleration
# - year
# - origin
# - cylinders
#
# Qualitative predictors in the  `Auto` dataset include:
# - origin
# - name

# %% [markdown]
# > Only origin is a categorical variable, the rest are numerical. Name is a nominal variable but can be converted into a categorical variable if the name is used to group vehicles by brand.

# %%
auto_df.dtypes.sort_values()
# Out:
# cylinders         int64
# weight            int64
# year              int64
# origin            int64
# mpg             float64
# displacement    float64
# acceleration    float64
# horsepower       object
# name             object
# dtype: object

# %%
auto_df['horsepower'].nunique()
# Out:
# 94

# %%
auto_df['horsepower'].shape
# Out:
# (397,)

# %%
auto_df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
auto_df[auto_df['horsepower'] == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0          ?    2046          19.0    71
# 126  21.0          6         200.0          ?    2875          17.0    74
# 330  40.9          4          85.0          ?    1835          17.3    80
# 336  23.6          4         140.0          ?    2905          14.3    80
# 354  34.5          4         100.0          ?    2320          15.8    81
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i

# %%
# seeing shape of the original data
auto_df.shape
# Out:
# (397, 9)

# %%
# making a duplicate of the original 
auto_df2 = auto_df.copy()

# %%
# removing questionable horsepowers
auto_df2 = auto_df2[auto_df2['horsepower'] != '?']
auto_df2.shape
# Out:
# (392, 9)

# %%
auto_df['origin'].nunique()
# Out:
# 3

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy. .min()

# %%
auto_df2['horsepower'] = auto_df2['horsepower'].astype('int')

# %%
auto_df2.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
numerical_columns = [col for col in auto_df.columns if col not in ['origin', 'name']]
numerical_columns
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'year']

# %%
num_auto_df = auto_df2[numerical_columns]

# %%
num_auto_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70

# %%
range_df = num_auto_df.max() - num_auto_df.min()
range_df
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# dtype: float64

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative predictor?

# %%
mean_df = num_auto_df.mean()
mean_df
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# dtype: float64

# %%
std_df = num_auto_df.std()
std_df
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# dtype: float64

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
# Remove rows from index 10 to 85
num_df2 = num_auto_df.drop(num_auto_df.index[10:86])
num_df2.reset_index(drop=True, inplace=True)

# %%
mean_num_df2 = num_df2.mean()
mean_num_df2
# Out:
# mpg               24.407595
# cylinders          5.373418
# displacement     187.512658
# horsepower       100.848101
# weight          2936.534810
# acceleration      15.717405
# year              77.136076
# dtype: float64

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your fndings

# %% [markdown]
# > **Auto dataset observations.**
# >
# >1. Feul efficency and acceleration of cars tends to improve over the years.
# >2. Lighter cars have faster acceleration and higher feul economy.
# >3. Vehicle mass, horsepower and displacement have strong positive corellations.

# %%
auto_corr = num_auto_df.corr()
mask = np.zeros_like(auto_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

auto_corr[mask] = np.nan
(auto_corr
    .style
    .background_gradient(
        cmap='coolwarm', vmin=-1, vmax=1
    )
    .highlight_null(color='#f1f1f1')
    .format(precision=2)
)
# Out:
# <style type="text/css">
# #T_c27b9_row0_col0, #T_c27b9_row0_col1, #T_c27b9_row0_col2, #T_c27b9_row0_col3, #T_c27b9_row0_col4, #T_c27b9_row0_col5, #T_c27b9_row0_col6, #T_c27b9_row1_col1, #T_c27b9_row1_col2, #T_c27b9_row1_col3, #T_c27b9_row1_col4, #T_c27b9_row1_col5, #T_c27b9_row1_col6, #T_c27b9_row2_col2, #T_c27b9_row2_col3, #T_c27b9_row2_col4, #T_c27b9_row2_col5, #T_c27b9_row2_col6, #T_c27b9_row3_col3, #T_c27b9_row3_col4, #T_c27b9_row3_col5, #T_c27b9_row3_col6, #T_c27b9_row4_col4, #T_c27b9_row4_col5, #T_c27b9_row4_col6, #T_c27b9_row5_col5, #T_c27b9_row5_col6, #T_c27b9_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_c27b9_row1_col0, #T_c27b9_row3_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c27b9_row2_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_c27b9_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_c27b9_row3_col1 {
#   background-color: #d0473d;
# ...

# %%
pd.plotting.scatter_matrix(num_auto_df, alpha=0.3, figsize=(14,8), diagonal='kde');

# %% [markdown]
# Displacement, Horsepower and Weight increases in a car's specs decrease the car's MPG value. Cars with faster accelerations tend to also have higer MPG values.

# %% [markdown]
# ### Boston Dataset

# %% [markdown]
# 10. `Boston` housing dataset excercises.

# %% [markdown]
# (a)  To begin, load in the Boston data set, which is part of the ISLP
# library.

# %%
boston_df = pd.read_csv(data / 'Boston.csv')
boston_df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat  medv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2

# %%
boston_catagorical = ['zn', 'indus', 'chas', 'rad', 'ptratio', 'tax']

# %% [markdown]
# (b) How many rows are in this data set?
# > 506
#
# How many columns?
# > 14
#
# What do the rows and columns represent?
# > Each row represents a suburb and each column represents a feature or metric related to that particular suburb. The metrics are as follows:
#
# > `crim`: per capita crime rate by town.
# `zn`: proportion of residential land zoned for lots over 25,000 sq.ft.
# `indus`: proportion of non-retail business acres per town.
# `chas`: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# `nox`: nitrogen oxides concentration (parts per 10 million).
# `rm`: average number of rooms per dwelling.
# `age`: proportion of owner-occupied units built prior to 1940.
# `dis`: weighted mean of distances to five Boston employment centres.
# `rad`: index of accessibility to radial highways.
# `tax`: full-value property-tax rate per $10,000.
# `ptratio`: pupil-teacher ratio by town.
# `lstat`: lower status of the population (percent).
# `medv`: median value of owner-occupied homes in $1000s.

# %%
boston_df.shape
# Out:
# (506, 14)

# %%
boston_df.drop('Unnamed: 0', axis=1, inplace=True)
boston_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# (c) Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your fndings.

# %% [markdown]
# 1. `medv`: The mean property value of owner occupied homes in Boston is around 22k.
# 2. `lsat`: On average most boston neighbourhoods are 10 percent accupied by a lower status of the population. Most neighborhoods have more (going up to 30%)
# 3. `ptratio`: The mean pupil-teacher ratio is around 20 pupils to 1 teacher. Many neighbourhoods have less pupils to teachers.
# 4. `tax`: The most common property tax rate in boston is around $250 USD per $10 000 USD.
# 5. `rad`: Most neighborhoods in Boston have an index of accessibility to major highways of between 0 to 10. Few fall between 10 to 20. A significant amount occur at an index of 20 and above.
# 6. `dis`: Most neighbourhoods fall within the range of 0 to 5 units of distance away from a major employment center.
# 7. `age`: On average the proportion of owner-occupied units built prior to 1940 is 95
# 8. `rm`: The mean number of rooms per houses for the neighbourhoods in the dataset is around 6.
# 9. `nox`: Most neighbourhoods in Boston fall between 0 and 0.5 parts per 10 million nitrogen oxide concentration levels.

# %%
boston_numerical = [
    col for col in boston_df.columns if col not in boston_catagorical
]
pd.plotting.scatter_matrix(boston_df[boston_numerical], alpha=0.3, figsize=(16,16), diagonal='kde')
print('done')
# Out:
# done

# %% [markdown]
# (d)  Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %% [markdown]
# > Yes. Per capita crime rate:
# > - has a positive correlations with nitrous oxide concentration.
# > - has a negative correlation with room number.
# > - has a positive correlation with age.
# > - has a negative correlation with distance from employment centers.
# > - has a positive correlation with lower status of the population percentages.
# > - has a negative correlation with the value of owner-occupied homes.

# %% [markdown]
# (e) Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.
#
# > 1. Suburbs 381, 419 and 406 show particularly high crime rates (over 65%)
# > 2. Suburbs 355 and 356 have the highest pupil to teacher ratio of 22.
# > 3. Theres an almost 90 percent difference in crime rate from the suburb with the lowest crime rate to the suburb with the highest.
# > 4. There's an about 9 pupil difference between the pupil to teacher ratio of the highest suburb and the lowest.

# %%
boston_df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# Crime rate has a range of 88.97%, ranging from less than 0.01% to 88.98%.

# %%
min_crim = boston_df['crim'].min()
max_crim = boston_df['crim'].max()

range_crim = max_crim - min_crim
print(range_crim)
boston_df.sort_values('crim', ascending=False).head()
# Out:
# 88.96988
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
#
#      ptratio  lstat  medv
# 380     20.2  17.21  10.4
# 418     20.2  20.62   8.8
# 405     20.2  22.98   5.0
# 410     20.2  10.11  15.0
# 414     20.2  36.98   7.0

# %% [markdown]
# Tax rate has a range of 524, ranging from less than 187 to 711.

# %%
min_tax = boston_df['tax'].min()
max_tax = boston_df['tax'].max()

range_tax = max_tax - min_tax
print(range_tax)

boston_df.sort_values('tax', ascending=False).head()
# Out:
# 524
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 492  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711     20.1
# 491  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711     20.1
# 490  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 489  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4  711     20.1
# 488  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4  711     20.1
#
#      lstat  medv
# 492  13.35  20.1
# 491  18.07  13.6
# 490  29.68   8.1
# 489  23.97   7.0
# 488  18.06  15.2

# %% [markdown]
# Pupil-teacher ratio has a range of 9.4, ranging from 12.6 to 20.2.

# %%
min_pt = boston_df['ptratio'].min()
max_pt = boston_df['ptratio'].max()

range_pt = max_pt - min_pt
print(range_pt)

boston_df.sort_values('ptratio', ascending=False).head()
# Out:
# 9.4
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
# 135  0.55778   0.0  21.89     0  0.624  6.335  98.2   2.1107    4  437
# 127  0.25915   0.0  21.89     0  0.624  5.693  96.0   1.7883    4  437
# 136  0.32264   0.0  21.89     0  0.624  5.942  93.5   1.9669    4  437
#
#      ptratio  lstat  medv
# 354     22.0   8.05  18.2
# 355     22.0   5.57  20.6
# 135     21.2  16.96  18.1
# 127     21.2  17.19  16.2
# 136     21.2  16.90  17.4

# %% [markdown]
# (d) How many of the suburbs in this data set bound the Charles
# river?
#
# `35`

# %%
boston_df['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# (g) What is the median pupil-teacher ratio among the towns in this
# data set?
#
# `19.05`

# %%
boston_df['ptratio'].median()
# Out:
# np.float64(19.05)

# %% [markdown]
# (h) Which suburb of Boston has lowest median value of owner-
# occupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your findings.

# %% [markdown]
# There are two suburbs sharing the lowest median value of owner occupied homes (`398` and `405`).
# These suburbs share the follwoing features in common:
# - No redidential land zoned for lots over 25 000 sq ft.
# - 18.1% non retail business land per acre per town.
# - Nitrogen oxide levels of 0.693 parts per 10 million
# - An average of about 5.5 rooms.
# - 100% composed of owner occupied units buit prior to 1940.
# - An index radial highway access of 24
# - A tax rate of 666
# - A Pupil teacter ratio of 20.2

# %%
boston_df[boston_df['medv'] == boston_df['medv'].min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %% [markdown]
# (i)  In this data set:
# - how many of the suburbs average more than seven rooms per dwelling? `64`
# - More than eight rooms per dwelling? `13`
# Comment on the suburbs that average more than eight rooms
# per dwelling.
#
# > The suburbs with houses averaging 8 rooms have an extremely low crime rates averaging 0.72 percent.
#
# > They have very low nitroux oxide values averaging 0.54 percent.The average median value of owner occupied homes is high at around 442 000 USD.
#
# > The suburbs in this bracket that bound the Charles river have significantly higher crime rates than their counterparts which do not.

# %%
boston_df['rm'][boston_df['rm'] > 7].count()
# Out:
# np.int64(64)

# %%
boston_df['rm'][boston_df['rm'] > 8].count()
# Out:
# np.int64(13)

# %%
boston_df[boston_df['rm'] > 8].sort_values('medv', ascending=False)
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# ...
